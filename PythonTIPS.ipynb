# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
list_keys = ['Country', 'Total']
list_values = [['United States', 'Soviet Union', 'United Kingdom'], [1118, 473, 273]]

# Zip the 2 lists together into one list of (key,value) tuples: zipped
zipped = list(zip(list_keys,list_values))

# Inspect the list using print()
print(zipped)

# Build a dictionary with the zipped list: data
data = dict(zipped)

# Build and inspect a DataFrame from the dictionary: df
df = pd.DataFrame(data)
print(df)
# Out:
# [('Country', ['United States', 'Soviet Union', 'United Kingdom']), ('Total', [1118, 473, 273])]
#           Country  Total
# 0   United States   1118
# 1    Soviet Union    473
# 2  United Kingdom    273

# %%
x=5
x
# Out:
# 5

# %%
x-2,x*2,x**2,x%2,x/2,x/float(2)
# Out:
# (3, 10, 25, 1, 2.5, 2.5)

# %% [markdown]
# Constant signal in Laplace noise
#
# pdf = $\frac{1}{2b}\exp\big(-\frac{|x-\theta|}{b}\big)$

# %%
N = 1000 #observations
t = 1 #parameter for an alternative
shift, scale = 0., 1.
smpl = np.random.laplace(shift, scale, N)

# %%
C = t/np.sqrt(N)
# Out:
# 0.031622776601683791

# %%
len(smpl)
signal1 = np.ones(N)*np.random.random()*
z = np.arange(0,2.*math.pi,2.*np.pi/len(smpl))
print(len(z))
signal2 = np.sin(z) + 1.0001
plt.plot(z,signal2,z,signal1)
plt.show()
# Out:
# 1000

# %%
smpl1 = signal1 + smpl
#smpl2 = signal2 + smpl
plt.plot(z,smpl,z,smpl1)
plt.show()

# %%
count, bins, ignored = plt.hist(smpl, 30, density=True)
count1, bins1, ignored1 = plt.hist(smpl1, 30, density=True)
#count2, bins2, ignored2 = plt.hist(smpl2, 30, density=True)
x = np.arange(-8., 8., .01)
pdf = np.exp(-abs(x-shift)/scale)/(2.*scale)
plt.plot(x, pdf)
plt.show()

# %%
help(np.ones)
# Out:
# Help on function ones in module numpy.core.numeric:
#
# ones(shape, dtype=None, order='C')
#     Return a new array of given shape and type, filled with ones.
#
#     Parameters
#     ----------
#     shape : int or sequence of ints
#         Shape of the new array, e.g., ``(2, 3)`` or ``2``.
#     dtype : data-type, optional
#         The desired data-type for the array, e.g., `numpy.int8`.  Default is
#         `numpy.float64`.
#     order : {'C', 'F'}, optional
#         Whether to store multidimensional data in C- or Fortran-contiguous
#         (row- or column-wise) order in memory.
#
#     Returns
#     -------
#     out : ndarray
#         Array of ones with the given shape, dtype, and order.
#
#     See Also
#     --------
#     zeros, ones_like
#
#     Examples
#     --------
#     >>> np.ones(5)
#     array([ 1.,  1.,  1.,  1.,  1.])
#
#     >>> np.ones((5,), dtype=np.int)
#     array([1, 1, 1, 1, 1])
#
#     >>> np.ones((2, 1))
#     array([[ 1.],
#            [ 1.]])
#
#     >>> s = (2,2)
#     >>> np.ones(s)
#     array([[ 1.,  1.],
#            [ 1.,  1.]])

# %%
help(python3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-29e63f07a481> in <module>()
# ----> 1 help(python3)
#
# NameError: name 'python3' is not defined
