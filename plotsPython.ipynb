# %%
import matplotlib.pyplot as plt
#step 1
x = [1,2,3,4]
y = [10,20,25,30]
#Step 2
fig = plt.figure() 
#Step 3
ax = fig.add_subplot(111) 
ax.plot(x, y, color='lightblue', linewidth=3) 
#Step 4,5
ax.scatter([2,4,6],
           [5,15,25],
           color='darkgreen',
           marker='^')
ax.set_xlim(1, 6.5)
plt.savefig('foo.png')
#Step 6
plt.show()

# %% [markdown]
# ## 1 Prepare The Data

# %% [markdown]
# ### 1D Data

# %%
import numpy as np
x = np.linspace(0, 10, 100)
y = np.cos(x)
z = np.sin(x)

# %% [markdown]
# ### 2D Data or Images

# %%
data = 2 * np.random.random((10, 10)) 
data2 = 3 * np.random.random((10, 10)) 
Y, X = np.mgrid[-3:3:100j, -3:3:100j] 
U = -1 - X**2 + Y
V = 1 + X - Y**2
from matplotlib.cbook import get_sample_data
img = np.load('bivariate_normal.npy')

# %% [markdown]
# ## 2 Create plot

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Figure

# %%
fig = plt.figure()
fig2 = plt.figure(figsize=plt.figaspect(2.0))

# %% [markdown]
# ### Axes

# %% [markdown]
# All ploting is done with respect to an Axes. In most cases, a subplot will fit your needs. A subplot is an axes on a grid system.

# %%
fig.add_axes()
ax1 = fig.add_subplot(221) # row-col-num
ax3 = fig.add_subplot(212)
fig3, axes = plt.subplots(nrows=2,ncols=2)
fig4, axes2 = plt.subplots(ncols=3)

# %% [markdown]
# ## 3 Ploting Routines

# %% [markdown]
# ### 1D Data

# %%
fig, ax = plt.subplots()
# Draw points with lines or markers connecting them
lines = ax.plot(x,y)
# Draw unconnected points, scaled or colored
ax.scatter(x,y)
# Plot vertical rectangles (constant width)
axes[0,0].bar([1,2,3],[3,4,5])
# Plot horiontal rectangles (constant height)
axes[1,0].barh([0.5,1,2.5],[0,1,2])
# Draw a horizontal line across axes
axes[1,1].axhline(0.45)
# Draw a vertical line across axes
axes[0,1].axvline(0.65)
# Draw filled polygons
ax.fill(x,y,color='blue')
# Fill between y-values and 0
ax.fill_between(x,y,color='yellow')

# %% [markdown]
# ### Vector Fields

# %%
# Add an arrow to the axe
axes[0,1].arrow(0,0,0.5,0.5)
# Plot a 2D field of arrows
axes[1,1].quiver(y,z)
# Plot a 2D field of arrows
axes[0,1].streamplot(X,Y,U,V)

# %% [markdown]
# ### Data Distributions

# %%
# Plot a histogram
ax1.hist(y)
# Make a box and whisker plot
ax3.boxplot(y)
# Make a violin plot
ax3.violinplot(z)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x109227e80>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1082dfb38>,
#  'cmins': <matplotlib.collections.LineCollection at 0x109230550>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1092307b8>}

# %% [markdown]
# ### 2D Data or Images

# %%
fig, ax = plt.subplots()
im = ax.imshow(img,
               cmap='gist_earth',
               interpolation='nearest',
               vmin=-2,
               vmax=2) # Colormapped or RGB arrays

# %%
# Pseudocolor plot of 2D array
axes2[0].pcolor(data2)
# Pseudocolor plot of 2D array
axes2[0].pcolormesh(data)
# Plot contours
CS = plt.contour(Y,X,U)
# Plot filled contours
axes2[2].contourf(data)
# Label a contour plot
axes2[2]= ax.clabel(CS)

# %% [markdown]
# ## 4 Customize Plot

# %% [markdown]
# ### Colors, Color Bars & Color Maps

# %%
plt.plot(x, x, x, x**2, x, x**3)
ax.plot(x, y, alpha = 0.4)
ax.plot(x, y, c='k')
fig.colorbar(im, orientation='horizontal')
im = ax.imshow(img,
               cmap='seismic')

# %% [markdown]
# ### Markers

# %%
fig, ax = plt.subplots()
ax.scatter(x,y,marker=".")
ax.plot(x,y,marker="o")

# %% [markdown]
# ### Linestyles

# %%
plt.plot(x,y,linewidth=4.0)
plt.plot(x,y,ls='solid')
plt.plot(x,y,ls='--')
plt.plot(x,y,'--',x**2,y**2,'-.')
plt.setp(lines,color='r',linewidth=4.0)
# Out:
# [None, None]

# %% [markdown]
# ### Text & Annotations

# %%
ax.text(1,
        -2.1,
        'Example Graph',
        style='italic')
# Out:
# Text(1, -2.1, 'Example Graph')

# %%
ax.annotate("Sine",
            xy=(8, 0),
            xycoords='data',
            xytext=(10.5, 0), textcoords='data', arrowprops=dict(arrowstyle="->",
            connectionstyle="arc3"),)
# Out:
# Text(10.5, 0, 'Sine')

# %% [markdown]
# ### Mathtext

# %%
plt.title(r'$sigma_i=15$', fontsize=20)
# Out:
# Text(0.5, 1.0, '$sigma_i=15$')

# %% [markdown]
# ### Limits, Legends & Layouts

# %%
### Limits & Autoscaling
# Add padding to a plot
ax.margins(x=0.0,y=0.1)
# Set the aspect ratio of the plot to 1
ax.axis('equal')
# Set limits for x-and y-axis
ax.set(xlim=[0,10.5],ylim=[-1.5,1.5])
# Set limits for x-axis
ax.set_xlim(0,10.5)
# Out:
# (0, 10.5)

# %%
### Legends
# Set a title and x-and y-axis labels
ax.set(title='An Example Axes',
       ylabel='Y-Axis',
       xlabel='X-Axis')
# No overlapping plot elements
ax.legend(loc='best')
# Out:
# No handles with labels found to put in legend.

# %%
### Ticks
# Manually set x-ticks
ax.xaxis.set(ticks=range(1,5),
                 ticklabels=[3,100,-12,"foo"])
# Make y-ticks longer and go in and out
ax.tick_params(axis='y',
               direction='inout',
               length=10)

# %%
### Subplot Spacing
# Adjust the spacing between subplots
fig3.subplots_adjust(wspace=0.5,
                    hspace=0.3,
                    left=0.125,
                    right=0.9,
                    top=0.9,
                    bottom=0.1)
# Fit subplot(s) in to the figure area
fig.tight_layout()

# %%
### Axis Spines
# Make the top axis line for a plot invisible
ax1.spines['top'].set_visible(False)
# Move the bo om axis line outward
ax1.spines['bottom'].set_position(('outward',10))

# %% [markdown]
# ## 5 Save Plot

# %% [markdown]
# ### Save figures

# %%
plt.savefig('foo.png')

# %%
# Save transparent figures
plt.savefig('foo.png', transparent=True)

# %% [markdown]
# ## 6 Show Plot

# %%
plt.show()

# %% [markdown]
# ## Close & Clear

# %%
# clear an axis
plt.cla()
# Clear the entire figure
plt.clf()
# Close a window
plt.close()
